# %% [markdown]
# # Assignment 5.2: Build and Apply Multilayer Perceptron

# %% [markdown]
# Name: Reyes, Paula Nicole G.
#
# Course and Section: CPE019 - CPE32S1
#
# Date of Submission: 06/23/2024
#
# Instructor: Engr. Roman M. Richard

# %% [markdown]
# # Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/rabieelkharoua/predict-pet-adoption-status-dataset

# %% [markdown]
# PROBLEM & SOLUTION

# %% [markdown]
# The Pet Adoption Dataset offers a thorough examination of the several variables that may affect a pet's chances of getting adopted from a shelter. This dataset contains comprehensive data on pets that are up for adoption, encompassing a range of traits and qualities.In order to ensure that more pets find their forever homes and to encourage research and efforts in this area, this dataset is being made available.

# %%
#mounting the google drive to google colab
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

#reading the csv file
df = pd.read_csv('/content/pet_adoption_data.csv')

# %%
df.head(10)
# Out:
#    PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        131  Orange   Large   5.039768
# 1    501  Rabbit            Rabbit         73   White   Large  16.086727
# 2    502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3    503    Bird          Parakeet         97   White   Small   3.339423
# 4    504  Rabbit            Rabbit        123    Gray   Large  20.498100
# 5    505     Dog          Labrador         70   Brown   Large  20.986261
# 6    506    Bird          Parakeet        169   Brown   Small  10.902613
# 7    507     Cat           Siamese         13  Orange   Large   7.252683
# 8    508    Bird          Parakeet         49   Brown  Medium  24.597598
# 9    509    Bird          Parakeet         60    Gray   Large   7.295994
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           1                0                 27          140              0
# ...

# %%
df['AdoptionLikelihood'] = df['AdoptionLikelihood'].astype('category')
df["AdoptionLikelihood"] = df["AdoptionLikelihood"].cat.codes
df['HealthCondition'] = df['HealthCondition'].astype('category')
df["HealthCondition"] = df["HealthCondition"].cat.codes
df['PreviousOwner'] = df['PreviousOwner'].astype('category')
df["PreviousOwner"] = df["PreviousOwner"].cat.codes
df['Vaccinated'] = df['Vaccinated'].astype('category')
df["Vaccinated"] = df["Vaccinated"].cat.codes

df.head(10)
# Out:
#    PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        131  Orange   Large   5.039768
# 1    501  Rabbit            Rabbit         73   White   Large  16.086727
# 2    502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3    503    Bird          Parakeet         97   White   Small   3.339423
# 4    504  Rabbit            Rabbit        123    Gray   Large  20.498100
# 5    505     Dog          Labrador         70   Brown   Large  20.986261
# 6    506    Bird          Parakeet        169   Brown   Small  10.902613
# 7    507     Cat           Siamese         13  Orange   Large   7.252683
# 8    508    Bird          Parakeet         49   Brown  Medium  24.597598
# 9    509    Bird          Parakeet         60    Gray   Large   7.295994
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           0                0                 27          140              0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.datasets import mnist
from sklearn.model_selection import train_test_split

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Flatten the images
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Normalize the pixel values
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# One-hot encode the target variable
y_train = np.eye(10)[y_train]
y_test = np.eye(10)[y_test]

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Define the MLP model
model = Sequential()
model.add(Flatten(input_shape=(28 * 28,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Make predictions on the testing set
predictions = model.predict(x_test)

# Convert the predictions to class labels
predictions = np.argmax(predictions, axis=1)

# Evaluate the model
print('Accuracy Score:')
print(accuracy_score(np.argmax(y_test, axis=1), predictions))
# Out:
# Epoch 1/10
# 1200/1200 [==============================] - 12s 9ms/step - loss: 0.2922 - accuracy: 0.9149 - val_loss: 0.1782 - val_accuracy: 0.9519
# Epoch 2/10
# 1200/1200 [==============================] - 10s 9ms/step - loss: 0.1325 - accuracy: 0.9606 - val_loss: 0.1745 - val_accuracy: 0.9513
# Epoch 3/10
# 1200/1200 [==============================] - 10s 8ms/step - loss: 0.1015 - accuracy: 0.9709 - val_loss: 0.1488 - val_accuracy: 0.9621
# Epoch 4/10
# 1200/1200 [==============================] - 10s 8ms/step - loss: 0.0879 - accuracy: 0.9748 - val_loss: 0.1302 - val_accuracy: 0.9638
# Epoch 5/10
# 1200/1200 [==============================] - 10s 9ms/step - loss: 0.0651 - accuracy: 0.9810 - val_loss: 0.1694 - val_accuracy: 0.9593
# Epoch 6/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0603 - accuracy: 0.9822 - val_loss: 0.1529 - val_accuracy: 0.9621
# Epoch 7/10
# ...

# %% [markdown]
# Evaluate the accuracy of your model.
#
# The MLP model can successfully comprehend the features in the MNIST dataset and attain a noticeably high accuracy, according to the training results. Over the course of the 10 epochs, both the accuracy and loss numbers grow gradually, indicating that the model is able to learn from the training set. Furthermore, validation accuracy increases steadily over epochs, albeit it behind training accuracy by a small margin. While this would suggest overfitting, the marginal difference suggests a minor issue rather than a significant one. In addition, the model performs admirably on the testing set, earning an accuracy score of 0.9669166666666666 in the process.
